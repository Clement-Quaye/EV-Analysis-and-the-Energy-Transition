# %% [markdown]
# ### EV Energy Analysis for the Energy Transition

# %%
#importing dependencies

import warnings
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
#wrangle function
def wrangle(filepath):
    #Read csv file into Data Frame
    df = pd.read_csv(filepath)
    return df

# %%
df1 = wrangle('./data/chargerdata2_2023_06_10_Anonymized.csv')
df2 = wrangle('./data/Advanced_EV_Rep/Report-Advanced EV Charging Report_20220708_061759_Anonymised.csv')
print("df shape:", df1.shape)
print("df shape:", df2.shape)
# Out:
# df shape: (6297793, 13)
# df shape: (9220, 18)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6297793 entries, 0 to 6297792
# Data columns (total 13 columns):
#  #   Column                                                                                                                                       Dtype
# ---  ------                                                                                                                                       -----
#  0   id                                                                                                                                           int64
#  1    "power"                                                                                                                                     int64
#  2    "timestamp"                                                                                                                                 int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9220 entries, 0 to 9219
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Vehicle                            9220 non-null   object
#  1   Start Date                         9220 non-null   object
#  2   End Date                           9220 non-null   object
#  3   Location                           9220 non-null   object
#  4   Zones                              9220 non-null   object
#  5   Zone Types                         9220 non-null   object
#  6   Start Charge %                     8990 non-null   object
#  7   End Charge %                       8971 non-null   object
#  8   Energy Added                       9220 non-null   float64
#  9   Max Power                          9220 non-null   float64
#  10  Electric Energy Economy            6569 non-null   float64
# ...

# %%
df2.head(2)
# Out:
#   Vehicle         Start Date           End Date Location Zones Zone Types  \
# 0  EV0055  Oct 03, 2021 0:00  Oct 03, 2021 5:27    Other  Area  Home Zone
# 1  EV0055  Oct 03, 2021 6:30  Oct 03, 2021 7:00    Other  Area  Home Zone
#
#   Start Charge % End Charge %  Energy Added  Max Power  \
# 0          34.5%        80.0%           0.0    -483.36
# 1          80.0%        79.0%           0.0    -483.36
#
#    Electric Energy Economy      Trip Stop Time Start Charge % For Session  \
# 0                     4.03  Oct 02, 2021 17:16                     34.50%
# 1                      NaN  Oct 02, 2021 17:16                     34.50%
#
#   End Charge % For Session Start Charge % Average For Device  \
# 0                   79.00%                            46.14%
# 1                   79.00%                            46.14%
#
#   End Charge % Average For Device Current  AC Voltage
# 0                          78.62%      AC       302.1
# ...

# %%
df2['Start Date'] = pd.to_datetime(df2['Start Date'])

df2.head()
# Out:
#   Vehicle          Start Date            End Date Location Zones Zone Types  \
# 0  EV0055 2021-10-03 00:00:00   Oct 03, 2021 5:27    Other  Area  Home Zone
# 1  EV0055 2021-10-03 06:30:00   Oct 03, 2021 7:00    Other  Area  Home Zone
# 2  EV0055 2021-10-06 00:00:00   Oct 06, 2021 2:41    Other  Area  Home Zone
# 3  EV0055 2021-10-06 06:30:00   Oct 06, 2021 7:00    Other  Area  Home Zone
# 4  EV0055 2021-10-09 16:00:00  Oct 09, 2021 16:21    Other  Area  Home Zone
#
#   Start Charge % End Charge %  Energy Added  Max Power  \
# 0          34.5%        80.0%           0.0    -483.36
# 1          80.0%        79.0%           0.0    -483.36
# 2          58.0%        80.0%           0.0    -483.36
# 3          80.0%        78.5%           0.0    -483.36
# 4          52.0%        52.0%           0.0       0.00
#
#    Electric Energy Economy      Trip Stop Time Start Charge % For Session  \
# 0                     4.03  Oct 02, 2021 17:16                     34.50%
# ...
